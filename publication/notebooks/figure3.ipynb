# %%
import seaborn as sns
import matplotlib.pyplot as plt
import pandas as pd
import numpy as np

# %%
df = pd.read_csv('../data/pyTCR_benchmarks.csv')
df
# Out:
#     Number_of_samples  CPU_time    Memory       Tool
# 0                   2      46.2   221.849      pyTCR
# 1                   4      52.0   405.012      pyTCR
# 2                   6      55.8   645.693      pyTCR
# 3                   8      62.4   854.325      pyTCR
# 4                  10      71.1   892.629      pyTCR
# ..                ...       ...       ...        ...
# 64                 38    4663.6  5501.750  Immunarch
# 65                 40    5413.6  5855.763  Immunarch
# 66                 42    5864.3  6123.639  Immunarch
# 67                 44    6376.4  6707.052  Immunarch
# 68                 46    6586.0  7193.892  Immunarch
#
# [69 rows x 4 columns]

# %% [markdown]
# ## Figure3a

# %%
sns.set_style("white") 
sns.set_context("talk") 

fig, ax = plt.subplots(figsize=(10, 10))
sns.lineplot(data=df, x="Number_of_samples", y="CPU_time", hue="Tool", style="Tool", markers=True)
#ax.set(yscale="log")
ax.set_ylabel('CPU Time (s)')
ax.set_xlabel('Number of samples')
sns.despine()

plt.savefig("../figures/main/figure3a.pdf",bbox_inches="tight")
plt.savefig("../figures/main/figure3a.png",bbox_inches="tight")

plt.show()

# %% [markdown]
# ## Figure3b

# %%
sns.set_style("white") 
sns.set_context("talk") 

fig, ax = plt.subplots(figsize=(10, 10))
sns.lineplot(data=df, x="Number_of_samples", y="Memory", hue="Tool", style="Tool", markers=True)
#ax.set(yscale="log")
ax.set_ylabel('Memory (MB)')
ax.set_xlabel('Number of samples')
sns.despine()

plt.savefig("../figures/main/figure3b.pdf",bbox_inches="tight")
plt.savefig("../figures/main/figure3b.png",bbox_inches="tight")

plt.show()
